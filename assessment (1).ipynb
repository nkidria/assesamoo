# %% [markdown]
# # My Jupyter notebook on IBM Waston Studio

# %% [markdown]
# **N'Kidria Dudley**
# Desired occupation: data scientist.

# %% [markdown]
# *I am interested in data science because of the creativity involved with the research processs. I enjoy thinking abstractly and can see myself enjoying solving problems and collecting data.*

# %% [markdown]
# ### In the next cell, my code is supposed to add single digit values to obtain an output value.

# %%
1+1
# Out:
# 2

# %% [markdown]
# By learning data science, I will be able to:
# 1. teach the youth some skills
# 2. ~buy a lot of things~
# 3. build generational wealth
# 4. buying [ This House](![DFD-010820PDFsNow-DFD-m%20small.jpg](attachment:DFD-010820PDFsNow-DFD-m%20small.jpg)
